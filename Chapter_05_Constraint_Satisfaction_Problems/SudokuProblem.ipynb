# %%
from kamgon import *

# %%
class SudokuProblem(CSPProblem):
    """
    ปัญหา Sudoku ที่ต้องการกรอกตัวเลข 1-9 ในตาราง 9x9 
    โดยแต่ละแถว แต่ละคอลัมน์ และแต่ละกล่อง 3x3 ต้องมีตัวเลข 1-9 ครบทุกตัว
    """
    
    def __init__(self, puzzle: List[List[int]]):
        """
        เริ่มต้นปัญหา Sudoku
        
        Args:
            puzzle: ตาราง 9x9 โดยช่องว่างแสดงด้วย 0
        """
        self.puzzle = puzzle
        variables = []
        domains = {}
        
        for row in range(9):
            for col in range(9):
                if puzzle[row][col] == 0:  # ช่องว่างที่ต้องกรอก
                    var_name = f"cell_{row}_{col}"
                    variables.append(var_name)
                    domains[var_name] = list(range(1, 10))
        
        super().__init__(variables, domains)
    
    def is_consistent(self, variable: str, value: Any, assignment: Dict[str, Any]) -> bool:
        """
        ตรวจสอบว่าการกรอกตัวเลขในช่องนี้ขัดแย้งกับกฎ Sudoku หรือไม่
        
        Args:
            variable: ชื่อตัวแปรที่แสดงถึงช่องในตาราง
            value: ตัวเลขที่จะกรอก
            assignment: การกรอกตัวเลขที่มีอยู่แล้ว
            
        Returns:
            True ถ้าสามารถกรอกตัวเลขนี้ได้โดยไม่ขัดแย้ง
        """
        row, col = self._parse_variable(variable)
        
        # สร้างตารางปัจจุบันรวมกับการกำหนดค่าใหม่
        current_board = [row[:] for row in self.puzzle]
        for var, val in assignment.items():
            if var != variable:
                var_row, var_col = self._parse_variable(var)
                current_board[var_row][var_col] = val
        
        # ตรวจสอบแถว
        for c in range(9):
            if c != col and current_board[row][c] == value:
                return False
        
        # ตรวจสอบคอลัมน์
        for r in range(9):
            if r != row and current_board[r][col] == value:
                return False
        
        # ตรวจสอบกล่อง 3x3
        box_row, box_col = 3 * (row // 3), 3 * (col // 3)
        for r in range(box_row, box_row + 3):
            for c in range(box_col, box_col + 3):
                if (r != row or c != col) and current_board[r][c] == value:
                    return False
        
        return True
    
    def _parse_variable(self, variable: str) -> tuple:
        """แยกชื่อตัวแปรเพื่อหา row และ column"""
        parts = variable.split('_')
        return int(parts[1]), int(parts[2])

# %%
# การใช้งาน Sudoku Problem
if __name__ == "__main__":
    print("\n=== Sudoku Problem ===")
    
    # ตัวอย่างปัญหา Sudoku (0 แสดงช่องว่าง)
    sudoku_puzzle = [
        [5, 3, 0, 0, 7, 0, 0, 0, 0],
        [6, 0, 0, 1, 9, 5, 0, 0, 0],
        [0, 9, 8, 0, 0, 0, 0, 6, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 3],
        [4, 0, 0, 8, 0, 3, 0, 0, 1],
        [7, 0, 0, 0, 2, 0, 0, 0, 6],
        [0, 6, 0, 0, 0, 0, 2, 8, 0],
        [0, 0, 0, 4, 1, 9, 0, 0, 5],
        [0, 0, 0, 0, 8, 0, 0, 7, 9]
    ]
    
    sudoku = SudokuProblem(sudoku_puzzle)
    
    print("ปัญหา Sudoku เริ่มต้น:")
    for row in sudoku_puzzle:
        print(' '.join(str(cell) if cell != 0 else '.' for cell in row))
    
    # แก้ปัญหาด้วย backtracking
    solution = backtracking_search(sudoku, verbose=True)
    
    if solution:
        print("\nคำตอบ Sudoku:")
        solved_board = [row[:] for row in sudoku_puzzle]
        for var, val in solution.items():
            row, col = sudoku._parse_variable(var)
            solved_board[row][col] = val
        
        for row in solved_board:
            print(' '.join(str(cell) for cell in row))
    else:
        print("ไม่พบคำตอบ")
# Out:
# === Sudoku Problem ===
# ปัญหา Sudoku เริ่มต้น:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
# กำลังสำรวจ node: 0/51 ตัวแปรได้รับการกำหนดค่า
# กำลังลอง cell_4_4 = 5
#   กำลังสำรวจ node: 1/51 ตัวแปรได้รับการกำหนดค่า
#   กำลังลอง cell_4_1 = 2
#     กำลังสำรวจ node: 2/51 ตัวแปรได้รับการกำหนดค่า
#     กำลังลอง cell_4_7 = 9
#       กำลังสำรวจ node: 3/51 ตัวแปรได้รับการกำหนดค่า
#       กำลังลอง cell_4_2 = 6
#         กำลังสำรวจ node: 4/51 ตัวแปรได้รับการกำหนดค่า
#         กำลังลอง cell_4_6 = 7
#           กำลังสำรวจ node: 5/51 ตัวแปรได้รับการกำหนดค่า
#           กำลังลอง cell_5_3 = 9
#             กำลังสำรวจ node: 6/51 ตัวแปรได้รับการกำหนดค่า
#             กำลังลอง cell_3_3 = 7
#               กำลังสำรวจ node: 7/51 ตัวแปรได้รับการกำหนดค่า
#               กำลังลอง cell_6_4 = 3
#                 กำลังสำรวจ node: 8/51 ตัวแปรได้รับการกำหนดค่า
#                 กำลังลอง cell_2_4 = 4
#                   กำลังสำรวจ node: 9/51 ตัวแปรได้รับการกำหนดค่า
#                   กำลังลอง cell_2_5 = 2
#                     กำลังสำรวจ node: 10/51 ตัวแปรได้รับการกำหนดค่า
#                     กำลังลอง cell_0_3 = 6
#                       กำลังสำรวจ node: 11/51 ตัวแปรได้รับการกำหนดค่า
#                       กำลังลอง cell_0_5 = 8
#                         กำลังสำรวจ node: 12/51 ตัวแปรได้รับการกำหนดค่า
#                         กำลังลอง cell_2_0 = 1
#                           กำลังสำรวจ node: 13/51 ตัวแปรได้รับการกำหนดค่า
#                           กำลังลอง cell_2_3 = 3
#                             กำลังสำรวจ node: 14/51 ตัวแปรได้รับการกำหนดค่า
#                             กำลังลอง cell_2_6 = 5
#                               กำลังสำรวจ node: 15/51 ตัวแปรได้รับการกำหนดค่า
#                               กำลังลอง cell_2_8 = 7
#                                 กำลังสำรวจ node: 16/51 ตัวแปรได้รับการกำหนดค่า
#                                 กำลังลอง cell_3_6 = 4
#                                   กำลังสำรวจ node: 17/51 ตัวแปรได้รับการกำหนดค่า
#                                   กำลังลอง cell_3_5 = 1
#                                     กำลังสำรวจ node: 18/51 ตัวแปรได้รับการกำหนดค่า
#                                     กำลังลอง cell_3_1 = 5
#                                       กำลังสำรวจ node: 19/51 ตัวแปรได้รับการกำหนดค่า
#                                       กำลังลอง cell_3_2 = 9
#                                         กำลังสำรวจ node: 20/51 ตัวแปรได้รับการกำหนดค่า
#                                         กำลังลอง cell_3_7 = 2
#                                           กำลังสำรวจ node: 21/51 ตัวแปรได้รับการกำหนดค่า
#                                           กำลังลอง cell_5_1 = 1
#                                             กำลังสำรวจ node: 22/51 ตัวแปรได้รับการกำหนดค่า
#                                             กำลังลอง cell_5_2 = 3
#                                               กำลังสำรวจ node: 23/51 ตัวแปรได้รับการกำหนดค่า
#                                               กำลังลอง cell_5_5 = 4
#                                                 กำลังสำรวจ node: 24/51 ตัวแปรได้รับการกำหนดค่า
#                                                 กำลังลอง cell_5_6 = 8
#                                                   กำลังสำรวจ node: 25/51 ตัวแปรได้รับการกำหนดค่า
#                                                   กำลังลอง cell_1_6 = 3
#                                                     กำลังสำรวจ node: 26/51 ตัวแปรได้รับการกำหนดค่า
#                                                     กำลังลอง cell_1_7 = 4
#                                                       กำลังสำรวจ node: 27/51 ตัวแปรได้รับการกำหนดค่า
#                                                       กำลังลอง cell_0_7 = 1
#                                                         กำลังสำรวจ node: 28/51 ตัวแปรได้รับการกำหนดค่า
#                                                         กำลังลอง cell_0_6 = 9
#                                                           กำลังสำรวจ node: 29/51 ตัวแปรได้รับการกำหนดค่า
#                                                           กำลังลอง cell_0_8 = 2
#                                                             กำลังสำรวจ node: 30/51 ตัวแปรได้รับการกำหนดค่า
#                                                             กำลังลอง cell_0_2 = 4
#                                                               กำลังสำรวจ node: 31/51 ตัวแปรได้รับการกำหนดค่า
#                                                               กำลังลอง cell_1_1 = 7
#                                                                 กำลังสำรวจ node: 32/51 ตัวแปรได้รับการกำหนดค่า
#                                                                 กำลังลอง cell_1_2 = 2
#                                                                   กำลังสำรวจ node: 33/51 ตัวแปรได้รับการกำหนดค่า
#                                                                   กำลังลอง cell_1_8 = 8
#                                                                     กำลังสำรวจ node: 34/51 ตัวแปรได้รับการกำหนดค่า
#                                                                     กำลังลอง cell_5_7 = 5
#                                                                       กำลังสำรวจ node: 35/51 ตัวแปรได้รับการกำหนดค่า
#                                                                       กำลังลอง cell_6_0 = 9
#                                                                         กำลังสำรวจ node: 36/51 ตัวแปรได้รับการกำหนดค่า
#                                                                         กำลังลอง cell_6_3 = 5
#                                                                           กำลังสำรวจ node: 37/51 ตัวแปรได้รับการกำหนดค่า
#                                                                           กำลังลอง cell_6_5 = 7
#                                                                             กำลังสำรวจ node: 38/51 ตัวแปรได้รับการกำหนดค่า
#                                                                             กำลังลอง cell_6_2 = 1
#                                                                               กำลังสำรวจ node: 39/51 ตัวแปรได้รับการกำหนดค่า
#                                                                               กำลังลอง cell_6_8 = 4
#                                                                                 กำลังสำรวจ node: 40/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                 กำลังลอง cell_7_1 = 8
#                                                                                   กำลังสำรวจ node: 41/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                   กำลังลอง cell_7_2 = 7
#                                                                                     กำลังสำรวจ node: 42/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                     กำลังลอง cell_7_6 = 6
#                                                                                       กำลังสำรวจ node: 43/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                       กำลังลอง cell_7_7 = 3
#                                                                                         กำลังสำรวจ node: 44/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                         กำลังลอง cell_7_0 = 2
#                                                                                           กำลังสำรวจ node: 45/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                           กำลังลอง cell_8_0 = 3
#                                                                                             กำลังสำรวจ node: 46/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                             กำลังลอง cell_8_1 = 4
#                                                                                               กำลังสำรวจ node: 47/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                               กำลังลอง cell_8_2 = 5
#                                                                                                 กำลังสำรวจ node: 48/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                                 กำลังลอง cell_8_3 = 2
#                                                                                                   กำลังสำรวจ node: 49/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                                   กำลังลอง cell_8_5 = 6
#                                                                                                     กำลังสำรวจ node: 50/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                                     กำลังลอง cell_8_6 = 1
#                                                                                                       กำลังสำรวจ node: 51/51 ตัวแปรได้รับการกำหนดค่า
#                                                                                                       พบคำตอบแล้ว!
#
# คำตอบ Sudoku:
# 5 3 4 6 7 8 9 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9

# %%
# การใช้งาน Sudoku Problem
if __name__ == "__main__":
    print("\n=== Sudoku Problem ===")
    
    # ตัวอย่างปัญหา Sudoku (0 แสดงช่องว่าง)
    sudoku_puzzle = [
        [5, 3, 0, 0, 7, 0, 0, 0, 0],
        [6, 0, 0, 1, 9, 5, 0, 0, 0],
        [0, 9, 8, 0, 0, 0, 0, 6, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 3],
        [4, 0, 0, 8, 0, 3, 0, 0, 1],
        [7, 0, 0, 0, 2, 0, 0, 0, 6],
        [0, 6, 0, 0, 0, 0, 2, 8, 0],
        [0, 0, 0, 4, 1, 9, 0, 0, 5],
        [0, 0, 0, 0, 8, 0, 0, 7, 9]
    ]
    
    sudoku = SudokuProblem(sudoku_puzzle)
    
    print("ปัญหา Sudoku เริ่มต้น:")
    for row in sudoku_puzzle:
        print(' '.join(str(cell) if cell != 0 else '.' for cell in row))

  
    initial_state = sudoku.initial_state
    goal_state = CSPState()    
    result_node = best_first_search(
            sudoku, 
            initial_state, 
            goal_state,
            f=lambda node, goal: sudoku.heuristic(node.state, goal),
            verbose=True
        )
    
    if solution:
        print("\nคำตอบ Sudoku:")
        solved_board = [row[:] for row in sudoku_puzzle]
        for var, val in solution.items():
            row, col = sudoku._parse_variable(var)
            solved_board[row][col] = val
        
        for row in solved_board:
            print(' '.join(str(cell) for cell in row))
    else:
        print("ไม่พบคำตอบ")
# Out:
# === Sudoku Problem ===
# ปัญหา Sudoku เริ่มต้น:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
# 1. โหนดปัจจุบัน: <Node CSPState({})>, f(n)=51
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5}) ด้วย f(n)=50
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 2. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5})>, f(n)=50
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2}) ด้วย f(n)=49
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 3. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2})>, f(n)=49
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9}) ด้วย f(n)=48
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 4. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9})>, f(n)=48
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6}) ด้วย f(n)=47
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 5. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6})>, f(n)=47
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7}) ด้วย f(n)=46
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 6. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7})>, f(n)=46
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9}) ด้วย f(n)=45
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 7. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9})>, f(n)=45
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7}) ด้วย f(n)=44
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 8. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7})>, f(n)=44
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3}) ด้วย f(n)=43
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 9. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3})>, f(n)=43
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4}) ด้วย f(n)=42
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 10. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4})>, f(n)=42
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2}) ด้วย f(n)=41
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 11. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2})>, f(n)=41
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6}) ด้วย f(n)=40
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 12. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6})>, f(n)=40
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8}) ด้วย f(n)=39
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 13. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8})>, f(n)=39
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1}) ด้วย f(n)=38
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 14. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1})>, f(n)=38
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3}) ด้วย f(n)=37
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 15. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3})>, f(n)=37
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5}) ด้วย f(n)=36
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 16. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5})>, f(n)=36
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7}) ด้วย f(n)=35
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 17. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7})>, f(n)=35
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4}) ด้วย f(n)=34
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 18. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4})>, f(n)=34
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1}) ด้วย f(n)=33
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 19. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1})>, f(n)=33
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5}) ด้วย f(n)=32
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 20. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5})>, f(n)=32
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9}) ด้วย f(n)=31
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 21. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9})>, f(n)=31
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2}) ด้วย f(n)=30
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 22. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2})>, f(n)=30
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1}) ด้วย f(n)=29
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 23. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1})>, f(n)=29
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3}) ด้วย f(n)=28
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 24. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3})>, f(n)=28
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4}) ด้วย f(n)=27
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 25. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4})>, f(n)=27
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8}) ด้วย f(n)=26
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 26. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8})>, f(n)=26
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3}) ด้วย f(n)=25
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 27. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3})>, f(n)=25
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4}) ด้วย f(n)=24
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 28. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4})>, f(n)=24
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1}) ด้วย f(n)=23
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 29. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1})>, f(n)=23
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9}) ด้วย f(n)=22
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 30. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9})>, f(n)=22
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2}) ด้วย f(n)=21
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 31. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2})>, f(n)=21
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4}) ด้วย f(n)=20
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 32. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4})>, f(n)=20
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7}) ด้วย f(n)=19
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 33. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7})>, f(n)=19
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2}) ด้วย f(n)=18
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 34. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2})>, f(n)=18
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8}) ด้วย f(n)=17
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 35. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8})>, f(n)=17
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5}) ด้วย f(n)=16
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 36. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5})>, f(n)=16
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9}) ด้วย f(n)=15
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 37. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9})>, f(n)=15
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5}) ด้วย f(n)=14
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 38. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5})>, f(n)=14
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7}) ด้วย f(n)=13
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 39. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7})>, f(n)=13
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1}) ด้วย f(n)=12
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 40. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1})>, f(n)=12
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4}) ด้วย f(n)=11
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 41. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4})>, f(n)=11
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8}) ด้วย f(n)=10
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 42. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8})>, f(n)=10
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7}) ด้วย f(n)=9
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 43. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7})>, f(n)=9
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6}) ด้วย f(n)=8
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 44. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6})>, f(n)=8
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3}) ด้วย f(n)=7
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 45. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3})>, f(n)=7
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2}) ด้วย f(n)=6
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 46. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2})>, f(n)=6
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3}) ด้วย f(n)=5
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 47. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3})>, f(n)=5
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4}) ด้วย f(n)=4
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 48. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4})>, f(n)=4
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5}) ด้วย f(n)=3
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 49. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5})>, f(n)=3
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2}) ด้วย f(n)=2
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 50. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2})>, f(n)=2
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2, 'cell_8_5': 6}) ด้วย f(n)=1
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 51. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2, 'cell_8_5': 6})>, f(n)=1
#   -> เพิ่มไปยัง waitlist: CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2, 'cell_8_5': 6, 'cell_8_6': 1}) ด้วย f(n)=0
#  :: waitlist ปัจจุบัน: <kamgon.PriorityQueue object at 0x000001F4B0A075E0>
# 52. โหนดปัจจุบัน: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2, 'cell_8_5': 6, 'cell_8_6': 1})>, f(n)=0
# พบเป้าหมาย: <Node CSPState({'cell_4_4': 5, 'cell_4_1': 2, 'cell_4_7': 9, 'cell_4_2': 6, 'cell_4_6': 7, 'cell_5_3': 9, 'cell_3_3': 7, 'cell_6_4': 3, 'cell_2_4': 4, 'cell_2_5': 2, 'cell_0_3': 6, 'cell_0_5': 8, 'cell_2_0': 1, 'cell_2_3': 3, 'cell_2_6': 5, 'cell_2_8': 7, 'cell_3_6': 4, 'cell_3_5': 1, 'cell_3_1': 5, 'cell_3_2': 9, 'cell_3_7': 2, 'cell_5_1': 1, 'cell_5_2': 3, 'cell_5_5': 4, 'cell_5_6': 8, 'cell_1_6': 3, 'cell_1_7': 4, 'cell_0_7': 1, 'cell_0_6': 9, 'cell_0_8': 2, 'cell_0_2': 4, 'cell_1_1': 7, 'cell_1_2': 2, 'cell_1_8': 8, 'cell_5_7': 5, 'cell_6_0': 9, 'cell_6_3': 5, 'cell_6_5': 7, 'cell_6_2': 1, 'cell_6_8': 4, 'cell_7_1': 8, 'cell_7_2': 7, 'cell_7_6': 6, 'cell_7_7': 3, 'cell_7_0': 2, 'cell_8_0': 3, 'cell_8_1': 4, 'cell_8_2': 5, 'cell_8_3': 2, 'cell_8_5': 6, 'cell_8_6': 1})>
#
# คำตอบ Sudoku:
# 5 3 4 6 7 8 9 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
